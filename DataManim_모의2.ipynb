# %% [markdown]
# <a href="https://colab.research.google.com/github/heyggun/bigdata_analysis_test/blob/main/DataManim_%EB%AA%A8%EC%9D%982.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 모의 2회차

# %% [markdown]
# ## 작업 1유형

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - 데이터 출처 : https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset (후처리 작업)
# - 데이터 설명 : 뇌졸증 발생여부 예측
# - dataurl : https://raw.githubusercontent.com/Datamanim/datarepo/main/stroke_/train.csv

# %%
DataURL = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/stroke_/train.csv'

df = pd.read_csv(DataURL)
display(df.head(3))
# Out:
#       id  gender age  hypertension  heart_disease ever_married work_type  \
# 0   1192  Female  31             0              0           No  Govt_job
# 1     77  Female  13             0              0           No  children
# 2  59200    Male  18             0              0           No   Private
#
#   Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 0          Rural              70.66  27.2   never smoked       0
# 1          Rural              85.81  18.6        Unknown       0
# 2          Urban              60.56  33.0   never smoked       0

# %% [markdown]
# Q1. 성별이 Male인 환자들의 age의 평균값은 ?

# %%
df['age'].value_counts()
# Out:
# 79     26
# 57     24
# 78     24
# 52     23
# 81     22
#        ..
# 3       7
# 35      7
# 12      6
# 4       6
# *82     1
# Name: age, Length: 84, dtype: int64

# %%
df['age'] = df['age'].str.replace('*','')
df['age'] = df['age'].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.loc[df['gender']=='Male']['age'].mean()
# Out:
# 44.68623481781376

# %% [markdown]
# Q2. bmi컬럼의 결측치를 bmi컬럼의 결측치를 제외한 나머지 값들의 중앙값으로 채웠을 경우 bmi 컬럼의 평균을 소숫점 이하 3자리 까지 구하여라

# %%
round(df['bmi'].fillna(df['bmi'].median()).mean(),3)
# Out:
# 29.166

# %% [markdown]
# Q3. bmi컬럼의 각 결측치들을 직전의 행의 bmi값으로 채웠을 경우 bmi 컬럼의 평균을 소숫점 이하 3자리 까지 구하여라

# %%
tmp = df.copy()
tmp['bmi'].fillna(method='ffill')
round(tmp['bmi'].mean(),3)
# Out:
# 29.198

# %% [markdown]
# Q4. bmi컬럼의 각 결측치들을 결측치를 가진 환자 나이대(10단위)의 평균 bmi 값으로 대체한 후 대체된 bmi 컬럼의 평균을 소숫점 이하 3자리 까지 구하여라

# %%
temp = df.copy()

mean = temp[temp['bmi'].notnull()].groupby(df['age']//10*10)['bmi'].mean()
mean
# Out:
# age
# 0     18.960784
# 10    24.477228
# 20    28.052747
# 30    31.751111
# 40    31.427097
# 50    31.894086
# 60    31.615873
# 70    30.447727
# 80    28.566667
# Name: bmi, dtype: float64

# %%
dic = {x:y for x,y in mean.items()}
dic
# Out:
# {0: 18.96078431372549,
#  10: 24.477227722772277,
#  20: 28.052747252747256,
#  30: 31.751111111111108,
#  40: 31.427096774193547,
#  50: 31.894086021505377,
#  60: 31.615873015873014,
#  70: 30.44772727272727,
#  80: 28.566666666666666}

# %%
temp.loc[temp['bmi'].isnull(), ['age','bmi']]
# Out:
#       age  bmi
# 67     54  NaN
# 87     33  NaN
# 103    51  NaN
# 105    78  NaN
# 106    77  NaN
# 113    48  NaN
# 119    49  NaN
# 178    31  NaN
# 185    45  NaN
# 192    79  NaN
# 203    71  NaN
# 229    76  NaN
# 261    65  NaN
# 329    76  NaN
# 336    58  NaN
# 365    78  NaN
# 368    40  NaN
# 380    34  NaN
# 387    72  NaN
# 397    78  NaN
# 447    78  NaN
# 464    66  NaN
# 515    16  NaN
# 516     1  NaN
# 519    25  NaN
# 532    76  NaN
# 550    61  NaN
# 589    75  NaN
# 590    79  NaN
# 602    76  NaN
# 608    37  NaN
# 611    63  NaN
# 627    72  NaN
# 653    66  NaN
# 660    52  NaN
# 663    51  NaN
# 666    75  NaN
# 701    63  NaN
# 784    64  NaN
# 822    40  NaN
# 840    39  NaN
# 866    34  NaN
# 897    45  NaN
# 915    78  NaN
# 926    67  NaN
# 952    71  NaN
# 1018   71  NaN
# 1055   59  NaN
# 1085   76  NaN
# 1098   10  NaN
# 1123   60  NaN
# 1131   59  NaN

# %%
idx = temp.loc[temp['bmi'].isnull(), ['age','bmi']].index
idx
# Out:
# Int64Index([  67,   87,  103,  105,  106,  113,  119,  178,  185,  192,  203,
#              229,  261,  329,  336,  365,  368,  380,  387,  397,  447,  464,
#              515,  516,  519,  532,  550,  589,  590,  602,  608,  611,  627,
#              653,  660,  663,  666,  701,  784,  822,  840,  866,  897,  915,
#              926,  952, 1018, 1055, 1085, 1098, 1123, 1131],
#            dtype='int64')

# %%
# 결측치 매핑

temp.loc[temp['bmi'].isnull(), 'bmi'] = (df[df['bmi'].isnull()].age//10*10).map(lambda x: dic[x])
temp['bmi'].mean()
# Out:
# 29.2627029367386

# %% [markdown]
# Q5. avg_glucose_level 컬럼의 값이 200이상인 데이터를 모두 199로 변경하고 stroke값이 1인 데이터의 avg_glucose_level값의 평균을 소수점이하 3자리 까지 구하여라

# %%
df.loc[df['avg_glucose_level']>=200, 'avg_glucose_level']  = 199

# %%
round(df.loc[df['stroke']==1]['avg_glucose_level'].mean(),3)
# Out:
# 125.188

# %% [markdown]
# ### 작업형 1유형_다른 데이터

# %% [markdown]
# - 데이터 출처 : https://www.kaggle.com/abcsds/pokemon (참고, 데이터 수정)
# - 데이터 설명 : 포켓몬 정보
# - data url = https://raw.githubusercontent.com/Datamanim/datarepo/main/pok/Pokemon.cs

# %%
DataURL = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/pok/Pokemon.csv'
df = pd.read_csv(DataURL)
display(df.head(3))
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %% [markdown]
# Q6. Attack컬럼의 값을 기준으로 내림차순정렬 했을때 상위 400위까지 포켓몬들과 401~800위까지의 포켓몬들에서 전설포켓몬(Legendary컬럼)의 숫자 차이는?

# %%
tmp1 = df.sort_values(by='Attack', ascending=False).iloc[:400]
display(tmp1.shape)
tmp2 = df.sort_values(by='Attack', ascending=False).iloc[400:801]
display(tmp2.shape)
# Out:
# (400, 13)
# (400, 13)

# %%
tmp1['Legendary'].sum() - tmp2['Legendary'].sum()
# Out:
# 57

# %% [markdown]
# Q7. Type 1 컬럼의 종류에 따른 Total 컬럼의 평균값을 내림차순 정렬했을때 상위 3번째 Type 1은 무엇인가?

# %%
df[['Type 1','Total']].groupby('Type 1')['Total'].mean().sort_values(ascending=False).index[2]
# Out:
# 'Flying'

# %% [markdown]
# Q8. 결측치가 존재하는 행을 모두 지운 후 처음부터 순서대로 60% 데이터를 추출하여 Defense컬럼의 1분위수를 구하여라

# %%
temp = df.copy()

temp.dropna().reset_index(drop=True, inplace=True)
temp.head(1)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Generation  Legendary
# 0     45           1      False

# %%
temp.iloc[:int(temp.shape[0] * 0.6)]['Defense'].quantile(0.25)
# Out:
# 50.0

# %% [markdown]
# Q9. Type 1 컬럼의 속성이 Fire인 포켓몬들의 Attack의 평균이상인 Water속성의 포켓몬 수를 구하여라

# %%
temp = df[df['Attack']>= df[df['Type 1']=='Fire']['Attack'].mean()]
temp[temp['Type 1']=='Water'].shape[0]
# Out:
# 37

# %%
target = df[df.Attack >= df[df['Type 1'] =='Fire'].Attack.mean()]
result = target[target['Type 1']=='Water'].shape[0]
print(result)
# Out:
# 37

# %% [markdown]
# Q10. 각 세대 중(Generation 컬럼)의 Speed와 Defense 컬럼의 차이(절댓값)이 가장 큰 세대는?

# %%
temp = df[['Generation', 'Speed','Defense']]
temp['gab'] = abs(temp['Speed'] - temp['Defense'])
temp[['Generation','gab']].value_counts().to_frame().reset_index().sort_values('gab', ascending=False).reset_index(drop=True).loc[0,'Generation']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2

# %%
result = abs(df.groupby(['Generation'])[['Speed','Defense']].mean().T.diff().T).sort_values('Defense').index[-1]
print(result)
# Out:
# 2

# %% [markdown]
# ## 작업 2유형

# %% [markdown]
# - 데이터 출처 : https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset (후처리 작업)
# - 데이터 설명 : 뇌졸증 발생여부 예측
# - train : https://raw.githubusercontent.com/Datamanim/datarepo/main/stroke_/train.csv
# - test : https://raw.githubusercontent.com/Datamanim/datarepo/main/stroke_/test.csv

# %%
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/stroke_/train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/stroke_/test.csv')

# %%
display(train.head(3))
display(test.head(3))
# Out:
#       id  gender age  hypertension  heart_disease ever_married work_type  \
# 0   1192  Female  31             0              0           No  Govt_job
# 1     77  Female  13             0              0           No  children
# 2  59200    Male  18             0              0           No   Private
#
#   Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 0          Rural              70.66  27.2   never smoked       0
# 1          Rural              85.81  18.6        Unknown       0
# 2          Urban              60.56  33.0   never smoked       0
#       id  gender  age  hypertension  heart_disease ever_married  \
# 0  47472  Female   58             0              0          Yes
# 1  36841    Male   78             1              0          Yes
# 2   3135  Female   73             0              0           No
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status
# 0        Private          Urban             107.26  38.6  formerly smoked
# 1  Self-employed          Rural              56.11  25.5  formerly smoked
# 2  Self-employed          Rural              69.35   NaN     never smoked

# %%
train.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status'],
#       dtype='object')

# %%
obj = train.select_dtypes(include='object').columns
num = train.select_dtypes(include='number').columns

print(obj)
print(num)
# Out:
# Index(['gender', 'age', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status'],
#       dtype='object')
# Index(['id', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'stroke'],
#       dtype='object')

# %%
temp_df = pd.concat([train.assign(ind='train'), test.assign(ind='test')])
temp_df
# Out:
#         id  gender age  hypertension  heart_disease ever_married work_type  \
# 0     1192  Female  31             0              0           No  Govt_job
# 1       77  Female  13             0              0           No  children
# 2    59200    Male  18             0              0           No   Private
# 3    24905  Female  65             0              0          Yes   Private
# 4    24257    Male   4             0              0           No  children
# ..     ...     ...  ..           ...            ...          ...       ...
# 927  40311  Female  58             0              0          Yes   Private
# 928  44281    Male  34             0              0           No   Private
# 929  11238    Male  46             0              0          Yes   Private
# 930  17308  Female  72             1              0          Yes   Private
# 931  24782    Male  36             0              0          Yes   Private
#
#     Residence_type  avg_glucose_level   bmi   smoking_status  stroke    ind
# 0            Rural              70.66  27.2     never smoked     0.0  train
# 1            Rural              85.81  18.6          Unknown     0.0  train
# 2            Urban              60.56  33.0     never smoked     0.0  train
# 3            Urban             205.77  46.0  formerly smoked     1.0  train
# 4            Rural              90.42  16.2          Unknown     0.0  train
# ..             ...                ...   ...              ...     ...    ...
# 927          Urban             149.75  27.0          Unknown     NaN   test
# 928          Rural              89.68  23.2           smokes     NaN   test
# 929          Rural              92.81  30.8          Unknown     NaN   test
# 930          Urban             221.79  30.0     never smoked     NaN   test
# 931          Rural              83.79  25.5           smokes     NaN   test
#
# [2069 rows x 13 columns]

# %%
temp_df['age']=temp_df['age'].apply(lambda x: int(str(x).replace('*','')))

# %%
train = temp_df[temp_df['ind']=='train'].reset_index(drop=True).drop(columns=['ind'])
test = temp_df[temp_df['ind']=='test'].reset_index(drop=True).drop(columns=['ind'])

# %%
display(train.head(1))
display(test.head(1))
# Out:
#      id  gender  age  hypertension  heart_disease ever_married work_type  \
# 0  1192  Female   31             0              0           No  Govt_job
#
#   Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 0          Rural              70.66  27.2   never smoked     0.0
#       id  gender  age  hypertension  heart_disease ever_married work_type  \
# 0  47472  Female   58             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             107.26  38.6  formerly smoked     NaN

# %%
print(train.isna().sum())
print(test.isna().sum())
# Out:
# id                    0
# gender                0
# age                   0
# hypertension          0
# heart_disease         0
# ever_married          0
# work_type             0
# Residence_type        0
# avg_glucose_level     0
# bmi                  52
# smoking_status        0
# stroke                0
# dtype: int64
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                   57
# smoking_status         0
# stroke               932
# dtype: int64

# %%
train['bmi'].fillna(train['bmi'].mean(),inplace=True)
test['bmi'].fillna(test['bmi'].mean(),inplace=True)

# %%
X_train = train.drop(columns=['id'])
X_test = test.drop(columns=['id','stroke'])

# %%
y_train = X_train['stroke']
X_train.drop(columns=['stroke'], inplace=True)

# %%
# 범주형 전처리

from sklearn.preprocessing import LabelEncoder

def Label_Encoder(df):
  for col in obj:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
  return df

# %%
X_trains = Label_Encoder(X_train)
X_tests = Label_Encoder(X_test)

# %%
num = num.tolist()
print(num)
num.remove('stroke')
num.remove('id')
print(num)
# Out:
# ['id', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi', 'stroke']
# ['hypertension', 'heart_disease', 'avg_glucose_level', 'bmi']

# %%
for col in num:
  print(col)
# Out:
# hypertension
# heart_disease
# avg_glucose_level
# bmi

# %%
# 수치형 전처리

from sklearn.preprocessing import StandardScaler

def Standard_Scaler(df):

  for col in num:
    Scaler = StandardScaler()
    df[col] = Scaler.fit_transform(df[col].values.reshape(-1,1))

  return df

# %%
X_trains = Standard_Scaler(X_trains)
X_tests = Standard_Scaler(X_tests)

# %%
# 모델링

from sklearn.model_selection import train_test_split

X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_trains, y_train,
                                                            test_size=0.3,
                                                            random_state=1234)

print(X_train_m.shape)
print(X_test_m.shape)
print(y_train_m.shape)
print(y_test_m.shape)
# Out:
# (795, 10)
# (342, 10)
# (795,)
# (342,)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_m, y_train_m)
pred = model.predict_proba(X_test_m)[:,1]

# %%
# 평가

from sklearn.metrics import roc_auc_score

print(roc_auc_score(y_test_m, pred))
# Out:
# 0.8086256513961266

# %%
# 모델링

from sklearn.model_selection import train_test_split

X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_trains, y_train,
                                                            test_size=0.3,
                                                            random_state=1234,
                                                            stratify =y_train)

print(X_train_m.shape)
print(X_test_m.shape)
print(y_train_m.shape)
print(y_test_m.shape)
# Out:
# (795, 10)
# (342, 10)
# (795,)
# (342,)

# %%
model = RandomForestClassifier()
model.fit(X_train_m, y_train_m)
pred = model.predict_proba(X_test_m)[:,1]

print(roc_auc_score(y_test_m, pred))
# Out:
# 0.8007859978932015

# %%
X_trains
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0          0   31     -0.367057      -0.271393             0          0
# 1          0   13     -0.367057      -0.271393             0          4
# 2          1   18     -0.367057      -0.271393             0          2
# 3          0   65     -0.367057      -0.271393             1          2
# 4          1    4     -0.367057      -0.271393             0          4
# ...      ...  ...           ...            ...           ...        ...
# 1132       0    1     -0.367057      -0.271393             0          4
# 1133       1    6     -0.367057      -0.271393             0          4
# 1134       1   81     -0.367057      -0.271393             1          2
# 1135       0   81      2.724376      -0.271393             1          2
# 1136       0   57      2.724376      -0.271393             1          2
#
#       Residence_type  avg_glucose_level       bmi  smoking_status
# 0                  0          -0.777431 -0.266810               2
# 1                  0          -0.459139 -1.415202               0
# 2                  1          -0.989626  0.507688               2
# 3                  1           2.061147  2.243631               1
# 4                  0          -0.362286 -1.735684               0
# ...              ...                ...       ...             ...
# 1132               0           0.052649 -1.188195               0
# 1133               0          -0.308502 -1.375142               0
# 1134               1           2.661595 -0.520524               1
# 1135               0          -0.572170  0.067025               2
# 1136               1           0.019875  1.188712               3
#
# [1137 rows x 10 columns]

# %%
model.fit(X_trains, y_train)
prediction = model.predict_proba(X_tests)[:,1]

my_pre_df = pd.DataFrame({'id': test['id'], 'stroke': prediction})
my_pre_df
# Out:
#         id  stroke
# 0    47472    0.14
# 1    36841    0.43
# 2     3135    0.21
# 3    65218    0.00
# 4     1847    0.02
# ..     ...     ...
# 927  40311    0.12
# 928  44281    0.01
# 929  11238    0.04
# 930  17308    0.21
# 931  24782    0.02
#
# [932 rows x 2 columns]

# %% [markdown]
# -------------------------------------------------

# %%
import pandas as pd
train= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/stroke_/train.csv')
test= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/stroke_/test.csv')

display(train.head())
display(test.head())



from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,classification_report
from sklearn.ensemble import RandomForestClassifier


# 전처리

train['age'] =train['age'].str.replace('*','').astype('int')
train['bmi'] = train['bmi'].fillna(train['bmi'].mean())
test['bmi'] = test['bmi'].fillna(test['bmi'].mean())
x = train.drop(columns =['id','stroke'])
xd = pd.get_dummies(x)
y = train['stroke']


#학습

x_train,x_test,y_train,y_test = train_test_split(xd,y,stratify =y ,random_state=1)
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
pred = rf.predict_proba(x_test)
print('test roc score : ',roc_auc_score(y_test,pred[:,1]))


# one-hot encoding시 train셋에만 존재하는 컬럼이 존재

test_preprocessing =pd.get_dummies(test.drop(columns=['id']))
test_preprocessing[list(set(x_train.columns) -set(test_preprocessing))] =0
test_preprocessing =test_preprocessing[x_train.columns]
test_pred = rf.predict_proba(test_preprocessing)

# 아래 코드 예측변수와 수험번호를 개인별로 변경하여 활용
# pd.DataFrame({'id': test.id, 'stroke': pred}).to_csv('003000000.csv', index=False)
datamanim_pred = pd.DataFrame({'id': test.id, 'stroke': test_pred[:,1]})
# Out:
#       id  gender age  hypertension  heart_disease ever_married work_type  \
# 0   1192  Female  31             0              0           No  Govt_job
# 1     77  Female  13             0              0           No  children
# 2  59200    Male  18             0              0           No   Private
# 3  24905  Female  65             0              0          Yes   Private
# 4  24257    Male   4             0              0           No  children
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Rural              70.66  27.2     never smoked       0
# 1          Rural              85.81  18.6          Unknown       0
# 2          Urban              60.56  33.0     never smoked       0
# 3          Urban             205.77  46.0  formerly smoked       1
# 4          Rural              90.42  16.2          Unknown       0
#       id  gender  age  hypertension  heart_disease ever_married  \
# 0  47472  Female   58             0              0          Yes
# 1  36841    Male   78             1              0          Yes
# 2   3135  Female   73             0              0           No
# 3  65218    Male    2             0              0           No
# 4   1847  Female   20             0              0           No
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status
# 0        Private          Urban             107.26  38.6  formerly smoked
# 1  Self-employed          Rural              56.11  25.5  formerly smoked
# 2  Self-employed          Rural              69.35   NaN     never smoked
# 3       children          Rural             109.10  20.0          Unknown
# 4       Govt_job          Rural              79.53   NaN     never smoked
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# test roc score :  0.8634286383876258

# %%
check = pd.concat([datamanim_pred, my_pre_df], axis=1)
# Out:
#         id  stroke     id  stroke
# 0    47472    0.14  47472    0.14
# 1    36841    0.51  36841    0.43
# 2     3135    0.30   3135    0.21
# 3    65218    0.00  65218    0.00
# 4     1847    0.02   1847    0.02
# ..     ...     ...    ...     ...
# 927  40311    0.24  40311    0.12
# 928  44281    0.04  44281    0.01
# 929  11238    0.09  11238    0.04
# 930  17308    0.18  17308    0.21
# 931  24782    0.15  24782    0.02
#
# [932 rows x 4 columns]
